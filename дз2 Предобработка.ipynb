# %% [markdown]
# **Домашнее задание: Предварительная обработка текстовых данных**

# %% [markdown]
# Здесь вам предстоит закрепить навыки нормализации текста, работы с регулярными выражениями, токенизации и удаления стоп-слов. Вы будете работать с первыми двумя главами Мцыри М.Ю. Лермонтова и выполнять различные этапы его предварительной обработки.

# %%
text = """

Немного лет тому назад,
Там, где, сливаяся, шумят,
Обнявшись, будто две сестры,
Струи Арагвы и Куры,
Был монастырь. Из-за горы
И нынче видит пешеход
Столбы обрушенных ворот,
И башни, и церковный свод;
Но не курится уж под ним
Кадильниц благовонный дым,
Не слышно пенье в поздний час
Молящих иноков за нас.
Теперь один старик седой,
Развалин страж полуживой,
Людьми и смертию забыт,
Сметает пыль с могильных плит,
Которых надпись говорит
О славе прошлой — и о том,
Как, удручен своим венцом,
Такой-то царь, в такой-то год,
Вручал России свой народ.
И божья благодать сошла
На Грузию! Она цвела
С тех пор в тени своих садов,
Не опасаяся врагов,
3а гранью дружеских штыков.

Однажды русский генерал
Из гор к Тифлису проезжал;
Ребенка пленного он вез.
Тот занемог, не перенес
Трудов далекого пути;
Он был, казалось, лет шести,
Как серна гор, пуглив и дик
И слаб и гибок, как тростник.
Но в нем мучительный недуг
Развил тогда могучий дух
Его отцов. Без жалоб он
Томился, даже слабый стон
Из детских губ не вылетал,
Он знаком пищу отвергал
И тихо, гордо умирал.
Из жалости один монах
Больного призрел, и в стенах
Хранительных остался он,
Искусством дружеским спасен.
Но, чужд ребяческих утех,
Сначала бегал он от всех,
Бродил безмолвен, одинок,
Смотрел, вздыхая, на восток,
Гоним неясною тоской
По стороне своей родной.
Но после к плену он привык,
Стал понимать чужой язык,
Был окрещен святым отцом
И, с шумным светом незнаком,
Уже хотел во цвете лет
Изречь монашеский обет,
Как вдруг однажды он исчез
Осенней ночью. Темный лес
Тянулся по горам кругом.
Три дня все поиски по нем
Напрасны были, но потом
Его в степи без чувств нашли
И вновь в обитель принесли.
Он страшно бледен был и худ
И слаб, как будто долгий труд,
Болезнь иль голод испытал.
Он на допрос не отвечал
И с каждым днем приметно вял.
И близок стал его конец;
Тогда пришел к нему чернец
С увещеваньем и мольбой;
И, гордо выслушав, больной
Привстал, собрав остаток сил,
И долго так он говорил:

"""

# %% [markdown]
# Задание 1: Регулярные выражения
#
# 1.    Напишите регулярное выражение, которое найдет все слова, которые начинаются с сочетания букв "**ста**".
#
# 2.    Напишите регулярное выражение, которое найдет все слова с сочетанием букв **ста** как в начале, так и внутри слов.
#
# 3. Модернизируйте это выражение так, чтобы буква **т** была опциональной (вместо нее может быть любой другой символ).
#
#
#
# *Не забывайте импортировать нужные библиотеки*

# %%
import re

# %%
search_result = re.findall(r'\bста\w*\b', text) 
print(search_result)
# Out:
# ['старик', 'стал']

# %%
search_result = re.findall(r'\b\w*ста\w*\b', text) 
print(search_result)
# Out:
# ['старик', 'остался', 'стал', 'Привстал', 'остаток']

# %%
search_result = re.findall(r'\b\w*ст?а\w*\b', text) 
print(search_result)
# Out:
# ['старик', 'садов', 'опасаяся', 'остался', 'стал', 'Привстал', 'остаток']

# %% [markdown]
# Задание 2: Нормализация текста
#
# 1.   Преобразуйте текст из переменной text к нижнему регистру.
#
# 2.   Удалите все символы пунктуации и переноса строки (\n), используя регулярные выражения.

# %%
import re

# %%
print(text)
# Out:
# Немного лет тому назад,
# Там, где, сливаяся, шумят,
# Обнявшись, будто две сестры,
# Струи Арагвы и Куры,
# Был монастырь. Из-за горы
# И нынче видит пешеход
# Столбы обрушенных ворот,
# И башни, и церковный свод;
# Но не курится уж под ним
# Кадильниц благовонный дым,
# Не слышно пенье в поздний час
# Молящих иноков за нас.
# Теперь один старик седой,
# Развалин страж полуживой,
# Людьми и смертию забыт,
# Сметает пыль с могильных плит,
# Которых надпись говорит
# О славе прошлой — и о том,
# Как, удручен своим венцом,
# Такой-то царь, в такой-то год,
# Вручал России свой народ.
# И божья благодать сошла
# На Грузию! Она цвела
# С тех пор в тени своих садов,
# Не опасаяся врагов,
# 3а гранью дружеских штыков.
#
# Однажды русский генерал
# Из гор к Тифлису проезжал;
# Ребенка пленного он вез.
# Тот занемог, не перенес
# Трудов далекого пути;
# Он был, казалось, лет шести,
# Как серна гор, пуглив и дик
# И слаб и гибок, как тростник.
# Но в нем мучительный недуг
# ...

# %%
lower_text = text.lower()  #1.   Преобразуйте текст из переменной text к нижнему регистру.
print(lower_text)
# Out:
# немного лет тому назад,
# там, где, сливаяся, шумят,
# обнявшись, будто две сестры,
# струи арагвы и куры,
# был монастырь. из-за горы
# и нынче видит пешеход
# столбы обрушенных ворот,
# и башни, и церковный свод;
# но не курится уж под ним
# кадильниц благовонный дым,
# не слышно пенье в поздний час
# молящих иноков за нас.
# теперь один старик седой,
# развалин страж полуживой,
# людьми и смертию забыт,
# сметает пыль с могильных плит,
# которых надпись говорит
# о славе прошлой — и о том,
# как, удручен своим венцом,
# такой-то царь, в такой-то год,
# вручал россии свой народ.
# и божья благодать сошла
# на грузию! она цвела
# с тех пор в тени своих садов,
# не опасаяся врагов,
# 3а гранью дружеских штыков.
#
# однажды русский генерал
# из гор к тифлису проезжал;
# ребенка пленного он вез.
# тот занемог, не перенес
# трудов далекого пути;
# он был, казалось, лет шести,
# как серна гор, пуглив и дик
# и слаб и гибок, как тростник.
# но в нем мучительный недуг
# ...

# %%
search_result = re.sub(r'[^а-яА-ЯёЁ\s]|\n', ' ', lower_text) # 2. Удалите все символы пунктуации и переноса строки (\n), используя регулярные выражения.
print(search_result)
# Out:
#   немного лет тому назад  там  где  сливаяся  шумят  обнявшись  будто две сестры  струи арагвы и куры  был монастырь  из за горы и нынче видит пешеход столбы обрушенных ворот  и башни  и церковный свод  но не курится уж под ним кадильниц благовонный дым  не слышно пенье в поздний час молящих иноков за нас  теперь один старик седой  развалин страж полуживой  людьми и смертию забыт  сметает пыль с могильных плит  которых надпись говорит о славе прошлой   и о том  как  удручен своим венцом  такой то царь  в такой то год  вручал россии свой народ  и божья благодать сошла на грузию  она цвела с тех пор в тени своих садов  не опасаяся врагов   а гранью дружеских штыков   однажды русский генерал из гор к тифлису проезжал  ребенка пленного он вез  тот занемог  не перенес трудов далекого пути  он был  казалось  лет шести  как серна гор  пуглив и дик и слаб и гибок  как тростник  но в нем мучительный недуг развил тогда могучий дух его отцов  без жалоб он томился  даже слабый стон из детских гу
# ...

# %%
text_norm = search_result
del search_result

# %%
print(text_norm)
# Out:
#   немного лет тому назад  там  где  сливаяся  шумят  обнявшись  будто две сестры  струи арагвы и куры  был монастырь  из за горы и нынче видит пешеход столбы обрушенных ворот  и башни  и церковный свод  но не курится уж под ним кадильниц благовонный дым  не слышно пенье в поздний час молящих иноков за нас  теперь один старик седой  развалин страж полуживой  людьми и смертию забыт  сметает пыль с могильных плит  которых надпись говорит о славе прошлой   и о том  как  удручен своим венцом  такой то царь  в такой то год  вручал россии свой народ  и божья благодать сошла на грузию  она цвела с тех пор в тени своих садов  не опасаяся врагов   а гранью дружеских штыков   однажды русский генерал из гор к тифлису проезжал  ребенка пленного он вез  тот занемог  не перенес трудов далекого пути  он был  казалось  лет шести  как серна гор  пуглив и дик и слаб и гибок  как тростник  но в нем мучительный недуг развил тогда могучий дух его отцов  без жалоб он томился  даже слабый стон из детских гу
# ...

# %% [markdown]
# Задание 3: Токенизация
#
#
# 1. Выполните токенизацию нормализованного текста на слова. Сколько токенов в тексте? А сколько уникальных?
# 2. Выполните токенизацию изначального текста на строки при помощи split('\n'). Отобразите сколько их.
# 3. Напишите цикл, который пройдет по всем токенам текста и сохранит в новой переменной те, которые начинаются с заглавной буквы.
# 4. *Модернизируйте цикл так, чтобы он сохранял в переменную слова с заглавной буквы за исключением тех, которые являются первыми в строке.

# %%
#Пример для 3.3
words = ["Привет", "мир", "Python", "программирование", "Функция"] #Создаем лист со словами
for word in range(len(words)): #Цикл для листа слов
  if words[word][0].isupper(): #Проверяем, является ли заглавным [0] символ каждого слова
    print(words[word])
# Out:
# Привет
# Python
# Функция

# %%
import re

# %%
print(text_norm)
# Out:
#   немного лет тому назад  там  где  сливаяся  шумят  обнявшись  будто две сестры  струи арагвы и куры  был монастырь  из за горы и нынче видит пешеход столбы обрушенных ворот  и башни  и церковный свод  но не курится уж под ним кадильниц благовонный дым  не слышно пенье в поздний час молящих иноков за нас  теперь один старик седой  развалин страж полуживой  людьми и смертию забыт  сметает пыль с могильных плит  которых надпись говорит о славе прошлой   и о том  как  удручен своим венцом  такой то царь  в такой то год  вручал россии свой народ  и божья благодать сошла на грузию  она цвела с тех пор в тени своих садов  не опасаяся врагов   а гранью дружеских штыков   однажды русский генерал из гор к тифлису проезжал  ребенка пленного он вез  тот занемог  не перенес трудов далекого пути  он был  казалось  лет шести  как серна гор  пуглив и дик и слаб и гибок  как тростник  но в нем мучительный недуг развил тогда могучий дух его отцов  без жалоб он томился  даже слабый стон из детских гу
# ...

# %%
naive_tokens = text_norm.split() # токенизируем
print(naive_tokens)
# Out:
# ['немного', 'лет', 'тому', 'назад', 'там', 'где', 'сливаяся', 'шумят', 'обнявшись', 'будто', 'две', 'сестры', 'струи', 'арагвы', 'и', 'куры', 'был', 'монастырь', 'из', 'за', 'горы', 'и', 'нынче', 'видит', 'пешеход', 'столбы', 'обрушенных', 'ворот', 'и', 'башни', 'и', 'церковный', 'свод', 'но', 'не', 'курится', 'уж', 'под', 'ним', 'кадильниц', 'благовонный', 'дым', 'не', 'слышно', 'пенье', 'в', 'поздний', 'час', 'молящих', 'иноков', 'за', 'нас', 'теперь', 'один', 'старик', 'седой', 'развалин', 'страж', 'полуживой', 'людьми', 'и', 'смертию', 'забыт', 'сметает', 'пыль', 'с', 'могильных', 'плит', 'которых', 'надпись', 'говорит', 'о', 'славе', 'прошлой', 'и', 'о', 'том', 'как', 'удручен', 'своим', 'венцом', 'такой', 'то', 'царь', 'в', 'такой', 'то', 'год', 'вручал', 'россии', 'свой', 'народ', 'и', 'божья', 'благодать', 'сошла', 'на', 'грузию', 'она', 'цвела', 'с', 'тех', 'пор', 'в', 'тени', 'своих', 'садов', 'не', 'опасаяся', 'врагов', 'а', 'гранью', 'дружеских', 'штыков', 'однажды', 'рус
# ...

# %%
print(len(naive_tokens)) # к-во токенов
# Out:
# 334

# %%
unique_tokens = set(naive_tokens) # только уникальные токены
print(unique_tokens)
# Out:
# {'испытал', 'поиски', 'слышно', 'забыт', 'нашли', 'час', 'людьми', 'стал', 'его', 'родной', 'тот', 'тянулся', 'три', 'труд', 'трудов', 'нем', 'иль', 'грузию', 'занемог', 'конец', 'пенье', 'потом', 'гордо', 'то', 'там', 'благодать', 'недуг', 'ним', 'светом', 'все', 'дружеским', 'отцом', 'хранительных', 'удручен', 'степи', 'обет', 'курится', 'исчез', 'сметает', 'были', 'ворот', 'восток', 'страж', 'вез', 'башни', 'тифлису', 'чужд', 'близок', 'за', 'надпись', 'кадильниц', 'пути', 'дик', 'плит', 'не', 'так', 'уже', 'которых', 'обнявшись', 'генерал', 'отцов', 'свод', 'поздний', 'чернец', 'отвечал', 'арагвы', 'перенес', 'старик', 'монастырь', 'увещеваньем', 'смертию', 'немного', 'допрос', 'был', 'монах', 'теперь', 'гранью', 'темный', 'прошлой', 'во', 'умирал', 'бегал', 'на', 'от', 'монашеский', 'чувств', 'бледен', 'стороне', 'осенней', 'каждым', 'и', 'призрел', 'а', 'видит', 'лет', 'стон', 'тоской', 'после', 'сил', 'плену', 'цвела', 'славе', 'изречь', 'седой', 'язык', 'одинок', 'казалось', 
# ...

# %%
print(len(unique_tokens)) # к-во уникальных токенов
# Out:
# 251

# %%
print(text) # исходный текст
# Out:
# Немного лет тому назад,
# Там, где, сливаяся, шумят,
# Обнявшись, будто две сестры,
# Струи Арагвы и Куры,
# Был монастырь. Из-за горы
# И нынче видит пешеход
# Столбы обрушенных ворот,
# И башни, и церковный свод;
# Но не курится уж под ним
# Кадильниц благовонный дым,
# Не слышно пенье в поздний час
# Молящих иноков за нас.
# Теперь один старик седой,
# Развалин страж полуживой,
# Людьми и смертию забыт,
# Сметает пыль с могильных плит,
# Которых надпись говорит
# О славе прошлой — и о том,
# Как, удручен своим венцом,
# Такой-то царь, в такой-то год,
# Вручал России свой народ.
# И божья благодать сошла
# На Грузию! Она цвела
# С тех пор в тени своих садов,
# Не опасаяся врагов,
# 3а гранью дружеских штыков.
#
# Однажды русский генерал
# Из гор к Тифлису проезжал;
# Ребенка пленного он вез.
# Тот занемог, не перенес
# Трудов далекого пути;
# Он был, казалось, лет шести,
# Как серна гор, пуглив и дик
# И слаб и гибок, как тростник.
# Но в нем мучительный недуг
# ...

# %%
text = '''Немного лет тому назад,
Там, где, сливаяся, шумят,
Обнявшись, будто две сестры,
Струи Арагвы и Куры,
Был монастырь. Из-за горы
И нынче видит пешеход
Столбы обрушенных ворот,
И башни, и церковный свод;
Но не курится уж под ним
Кадильниц благовонный дым,
Не слышно пенье в поздний час
Молящих иноков за нас.
Теперь один старик седой,
Развалин страж полуживой,
Людьми и смертию забыт,
Сметает пыль с могильных плит,
Которых надпись говорит
О славе прошлой — и о том,
Как, удручен своим венцом,
Такой-то царь, в такой-то год,
Вручал России свой народ.
И божья благодать сошла
На Грузию! Она цвела
С тех пор в тени своих садов,
Не опасаяся врагов,
3а гранью дружеских штыков.

Однажды русский генерал
Из гор к Тифлису проезжал;
Ребенка пленного он вез.
Тот занемог, не перенес
Трудов далекого пути;
Он был, казалось, лет шести,
Как серна гор, пуглив и дик
И слаб и гибок, как тростник.
Но в нем мучительный недуг
Развил тогда могучий дух
Его отцов. Без жалоб он
Томился, даже слабый стон
Из детских губ не вылетал,
Он знаком пищу отвергал
И тихо, гордо умирал.
Из жалости один монах
Больного призрел, и в стенах
Хранительных остался он,
Искусством дружеским спасен.
Но, чужд ребяческих утех,
Сначала бегал он от всех,
Бродил безмолвен, одинок,
Смотрел, вздыхая, на восток,
Гоним неясною тоской
По стороне своей родной.
Но после к плену он привык,
Стал понимать чужой язык,
Был окрещен святым отцом
И, с шумным светом незнаком,
Уже хотел во цвете лет
Изречь монашеский обет,
Как вдруг однажды он исчез
Осенней ночью. Темный лес
Тянулся по горам кругом.
Три дня все поиски по нем
Напрасны были, но потом
Его в степи без чувств нашли
И вновь в обитель принесли.
Он страшно бледен был и худ
И слаб, как будто долгий труд,
Болезнь иль голод испытал.
Он на допрос не отвечал
И с каждым днем приметно вял.
И близок стал его конец;
Тогда пришел к нему чернец
С увещеваньем и мольбой;
И, гордо выслушав, больной
Привстал, собрав остаток сил,
И долго так он говорил:'''
text              #деление по пробелу
# Out:
# 'Немного лет тому назад,\nТам, где, сливаяся, шумят,\nОбнявшись, будто две сестры,\nСтруи Арагвы и Куры,\nБыл монастырь. Из-за горы\nИ нынче видит пешеход\nСтолбы обрушенных ворот,\nИ башни, и церковный свод;\nНо не курится уж под ним\nКадильниц благовонный дым,\nНе слышно пенье в поздний час\nМолящих иноков за нас.\nТеперь один старик седой,\nРазвалин страж полуживой,\nЛюдьми и смертию забыт,\nСметает пыль с могильных плит,\nКоторых надпись говорит\nО славе прошлой — и о том,\nКак, удручен своим венцом,\nТакой-то царь, в такой-то год,\nВручал России свой народ.\nИ божья благодать сошла\nНа Грузию! Она цвела\nС тех пор в тени своих садов,\nНе опасаяся врагов,\n3а гранью дружеских штыков.\n\nОднажды русский генерал\nИз гор к Тифлису проезжал;\nРебенка пленного он вез.\nТот занемог, не перенес\nТрудов далекого пути;\nОн был, казалось, лет шести,\nКак серна гор, пуглив и дик\nИ слаб и гибок, как тростник.\nНо в нем мучительный недуг\nРазвил тогда могучий дух\nЕго отцов. Без жалоб он\nТо
# ...

# %%
native_tokens = text.split()
print(native_tokens)
# Out:
# ['Немного', 'лет', 'тому', 'назад,', 'Там,', 'где,', 'сливаяся,', 'шумят,', 'Обнявшись,', 'будто', 'две', 'сестры,', 'Струи', 'Арагвы', 'и', 'Куры,', 'Был', 'монастырь.', 'Из-за', 'горы', 'И', 'нынче', 'видит', 'пешеход', 'Столбы', 'обрушенных', 'ворот,', 'И', 'башни,', 'и', 'церковный', 'свод;', 'Но', 'не', 'курится', 'уж', 'под', 'ним', 'Кадильниц', 'благовонный', 'дым,', 'Не', 'слышно', 'пенье', 'в', 'поздний', 'час', 'Молящих', 'иноков', 'за', 'нас.', 'Теперь', 'один', 'старик', 'седой,', 'Развалин', 'страж', 'полуживой,', 'Людьми', 'и', 'смертию', 'забыт,', 'Сметает', 'пыль', 'с', 'могильных', 'плит,', 'Которых', 'надпись', 'говорит', 'О', 'славе', 'прошлой', '—', 'и', 'о', 'том,', 'Как,', 'удручен', 'своим', 'венцом,', 'Такой-то', 'царь,', 'в', 'такой-то', 'год,', 'Вручал', 'России', 'свой', 'народ.', 'И', 'божья', 'благодать', 'сошла', 'На', 'Грузию!', 'Она', 'цвела', 'С', 'тех', 'пор', 'в', 'тени', 'своих', 'садов,', 'Не', 'опасаяся', 'врагов,', '3а', 'гранью', 'дружеских', '
# ...

# %%
print(len(native_tokens)) # к-во
# Out:
# 332

# %%
words = native_tokens    #Создаем лист со словами
for word in range(len(words)): #Цикл для листа слов
  if words[word][0].isupper(): #Проверяем, является ли заглавным [0] символ каждого слова
    print(words[word])
# Out:
# Немного
# Там,
# Обнявшись,
# Струи
# Арагвы
# Куры,
# Был
# Из-за
# И
# Столбы
# И
# Но
# Кадильниц
# Не
# Молящих
# Теперь
# Развалин
# Людьми
# Сметает
# Которых
# О
# Как,
# Такой-то
# Вручал
# России
# И
# На
# Грузию!
# Она
# С
# Не
# Однажды
# Из
# Тифлису
# Ребенка
# Тот
# Трудов
# Он
# Как
# И
# Но
# Развил
# Его
# Без
# Томился,
# Из
# Он
# И
# Из
# Больного
# Хранительных
# Искусством
# Но,
# Сначала
# Бродил
# Смотрел,
# Гоним
# По
# Но
# Стал
# Был
# И,
# Уже
# Изречь
# Как
# Осенней
# Темный
# Тянулся
# Три
# Напрасны
# Его
# И
# Он
# И
# Болезнь
# Он
# И
# И
# Тогда
# С
# И,
# Привстал,
# И

# %% [markdown]
# Задание 4: Удаление стоп слов
#
#
# 1. Импортируйте список стоп-слов для русского языка из NLTK.
# 2. Напишите цикл, который пройдет по всем токенам и вернет новый список токенов без стоп-слов.
# 3. Сколько слов осталось в тексте? А уникальных?
# 4. *При помощи регулярного выражения найдите все слова с сочетанием букв 'бол' (с опциональной о) внутри слова. Добавьте их к стоп-словам и удалите из текста. Сколько осталось слов в тексте?

# %%
# %pip install nltk
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Sony\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sony\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
nltk_stopwords_ru = stopwords.words('russian')
print(nltk_stopwords_ru)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'в
# ...

# %%
print(text)
# Out:
# Немного лет тому назад,
# Там, где, сливаяся, шумят,
# Обнявшись, будто две сестры,
# Струи Арагвы и Куры,
# Был монастырь. Из-за горы
# И нынче видит пешеход
# Столбы обрушенных ворот,
# И башни, и церковный свод;
# Но не курится уж под ним
# Кадильниц благовонный дым,
# Не слышно пенье в поздний час
# Молящих иноков за нас.
# Теперь один старик седой,
# Развалин страж полуживой,
# Людьми и смертию забыт,
# Сметает пыль с могильных плит,
# Которых надпись говорит
# О славе прошлой — и о том,
# Как, удручен своим венцом,
# Такой-то царь, в такой-то год,
# Вручал России свой народ.
# И божья благодать сошла
# На Грузию! Она цвела
# С тех пор в тени своих садов,
# Не опасаяся врагов,
# 3а гранью дружеских штыков.
#
# Однажды русский генерал
# Из гор к Тифлису проезжал;
# Ребенка пленного он вез.
# Тот занемог, не перенес
# Трудов далекого пути;
# Он был, казалось, лет шести,
# Как серна гор, пуглив и дик
# И слаб и гибок, как тростник.
# Но в нем мучительный недуг
# ...

# %%
print(text_norm) # из 2 задания (нижний регистр+без пунктуации)
# Out:
#   немного лет тому назад  там  где  сливаяся  шумят  обнявшись  будто две сестры  струи арагвы и куры  был монастырь  из за горы и нынче видит пешеход столбы обрушенных ворот  и башни  и церковный свод  но не курится уж под ним кадильниц благовонный дым  не слышно пенье в поздний час молящих иноков за нас  теперь один старик седой  развалин страж полуживой  людьми и смертию забыт  сметает пыль с могильных плит  которых надпись говорит о славе прошлой   и о том  как  удручен своим венцом  такой то царь  в такой то год  вручал россии свой народ  и божья благодать сошла на грузию  она цвела с тех пор в тени своих садов  не опасаяся врагов   а гранью дружеских штыков   однажды русский генерал из гор к тифлису проезжал  ребенка пленного он вез  тот занемог  не перенес трудов далекого пути  он был  казалось  лет шести  как серна гор  пуглив и дик и слаб и гибок  как тростник  но в нем мучительный недуг развил тогда могучий дух его отцов  без жалоб он томился  даже слабый стон из детских гу
# ...

# %%
naive_tokens = text_norm.split() # токенизация из 2 задания
print(naive_tokens)
# Out:
# ['немного', 'лет', 'тому', 'назад', 'там', 'где', 'сливаяся', 'шумят', 'обнявшись', 'будто', 'две', 'сестры', 'струи', 'арагвы', 'и', 'куры', 'был', 'монастырь', 'из', 'за', 'горы', 'и', 'нынче', 'видит', 'пешеход', 'столбы', 'обрушенных', 'ворот', 'и', 'башни', 'и', 'церковный', 'свод', 'но', 'не', 'курится', 'уж', 'под', 'ним', 'кадильниц', 'благовонный', 'дым', 'не', 'слышно', 'пенье', 'в', 'поздний', 'час', 'молящих', 'иноков', 'за', 'нас', 'теперь', 'один', 'старик', 'седой', 'развалин', 'страж', 'полуживой', 'людьми', 'и', 'смертию', 'забыт', 'сметает', 'пыль', 'с', 'могильных', 'плит', 'которых', 'надпись', 'говорит', 'о', 'славе', 'прошлой', 'и', 'о', 'том', 'как', 'удручен', 'своим', 'венцом', 'такой', 'то', 'царь', 'в', 'такой', 'то', 'год', 'вручал', 'россии', 'свой', 'народ', 'и', 'божья', 'благодать', 'сошла', 'на', 'грузию', 'она', 'цвела', 'с', 'тех', 'пор', 'в', 'тени', 'своих', 'садов', 'не', 'опасаяся', 'врагов', 'а', 'гранью', 'дружеских', 'штыков', 'однажды', 'рус
# ...

# %%
nltk_stopwords_ru = stopwords.words('russian')
list_no_stop_words = [] # список
for token in (naive_tokens): 
    if token not in nltk_stopwords_ru:
        list_no_stop_words.append(token) # новый список токенов без стоп-слов.
print(list_no_stop_words)
# Out:
# ['немного', 'лет', 'тому', 'назад', 'сливаяся', 'шумят', 'обнявшись', 'две', 'сестры', 'струи', 'арагвы', 'куры', 'монастырь', 'горы', 'нынче', 'видит', 'пешеход', 'столбы', 'обрушенных', 'ворот', 'башни', 'церковный', 'свод', 'курится', 'кадильниц', 'благовонный', 'дым', 'слышно', 'пенье', 'поздний', 'час', 'молящих', 'иноков', 'старик', 'седой', 'развалин', 'страж', 'полуживой', 'людьми', 'смертию', 'забыт', 'сметает', 'пыль', 'могильных', 'плит', 'которых', 'надпись', 'говорит', 'славе', 'прошлой', 'удручен', 'своим', 'венцом', 'царь', 'год', 'вручал', 'россии', 'свой', 'народ', 'божья', 'благодать', 'сошла', 'грузию', 'цвела', 'тех', 'пор', 'тени', 'своих', 'садов', 'опасаяся', 'врагов', 'гранью', 'дружеских', 'штыков', 'однажды', 'русский', 'генерал', 'гор', 'тифлису', 'проезжал', 'ребенка', 'пленного', 'вез', 'занемог', 'перенес', 'трудов', 'далекого', 'пути', 'казалось', 'лет', 'шести', 'серна', 'гор', 'пуглив', 'дик', 'слаб', 'гибок', 'тростник', 'нем', 'мучительный', 'недуг'
# ...

# %%
print(len(list_no_stop_words)) # к-во оставшихся слов
# Out:
# 215

# %%
unique_tokens = set(naive_tokens) # только уникальные токены из 2 задания
print(unique_tokens)
# Out:
# {'испытал', 'поиски', 'слышно', 'забыт', 'нашли', 'час', 'людьми', 'стал', 'его', 'родной', 'тот', 'тянулся', 'три', 'труд', 'трудов', 'нем', 'иль', 'грузию', 'занемог', 'конец', 'пенье', 'потом', 'гордо', 'то', 'там', 'благодать', 'недуг', 'ним', 'светом', 'все', 'дружеским', 'отцом', 'хранительных', 'удручен', 'степи', 'обет', 'курится', 'исчез', 'сметает', 'были', 'ворот', 'восток', 'страж', 'вез', 'башни', 'тифлису', 'чужд', 'близок', 'за', 'надпись', 'кадильниц', 'пути', 'дик', 'плит', 'не', 'так', 'уже', 'которых', 'обнявшись', 'генерал', 'отцов', 'свод', 'поздний', 'чернец', 'отвечал', 'арагвы', 'перенес', 'старик', 'монастырь', 'увещеваньем', 'смертию', 'немного', 'допрос', 'был', 'монах', 'теперь', 'гранью', 'темный', 'прошлой', 'во', 'умирал', 'бегал', 'на', 'от', 'монашеский', 'чувств', 'бледен', 'стороне', 'осенней', 'каждым', 'и', 'призрел', 'а', 'видит', 'лет', 'стон', 'тоской', 'после', 'сил', 'плену', 'цвела', 'славе', 'изречь', 'седой', 'язык', 'одинок', 'казалось', 
# ...

# %%
nltk_stopwords_ru = stopwords.words('russian')
list_no_stop_words = [] # список
for token in (unique_tokens): 
    if token not in nltk_stopwords_ru:
        list_no_stop_words.append(token) # новый список токенов без стоп-слов.
print(list_no_stop_words)
# Out:
# ['испытал', 'поиски', 'слышно', 'забыт', 'нашли', 'час', 'людьми', 'стал', 'родной', 'тянулся', 'труд', 'трудов', 'нем', 'иль', 'грузию', 'занемог', 'конец', 'пенье', 'гордо', 'благодать', 'недуг', 'светом', 'дружеским', 'отцом', 'хранительных', 'удручен', 'степи', 'обет', 'курится', 'исчез', 'сметает', 'ворот', 'восток', 'страж', 'вез', 'башни', 'тифлису', 'чужд', 'близок', 'надпись', 'кадильниц', 'пути', 'дик', 'плит', 'которых', 'обнявшись', 'генерал', 'отцов', 'свод', 'поздний', 'чернец', 'отвечал', 'арагвы', 'перенес', 'старик', 'монастырь', 'увещеваньем', 'смертию', 'немного', 'допрос', 'монах', 'гранью', 'темный', 'прошлой', 'умирал', 'бегал', 'монашеский', 'чувств', 'бледен', 'стороне', 'осенней', 'каждым', 'призрел', 'видит', 'лет', 'стон', 'тоской', 'сил', 'плену', 'цвела', 'славе', 'изречь', 'седой', 'язык', 'одинок', 'казалось', 'опасаяся', 'дружеских', 'гибок', 'хотел', 'садов', 'говорил', 'иноков', 'неясною', 'дым', 'две', 'дня', 'выслушав', 'врагов', 'вручал', 'горы', 
# ...

# %%
print(len(unique_tokens)) # к-во уникальных токенов (не изменилось)
# Out:
# 251

# %%
print(text_norm)
# Out:
#   немного лет тому назад  там  где  сливаяся  шумят  обнявшись  будто две сестры  струи арагвы и куры  был монастырь  из за горы и нынче видит пешеход столбы обрушенных ворот  и башни  и церковный свод  но не курится уж под ним кадильниц благовонный дым  не слышно пенье в поздний час молящих иноков за нас  теперь один старик седой  развалин страж полуживой  людьми и смертию забыт  сметает пыль с могильных плит  которых надпись говорит о славе прошлой   и о том  как  удручен своим венцом  такой то царь  в такой то год  вручал россии свой народ  и божья благодать сошла на грузию  она цвела с тех пор в тени своих садов  не опасаяся врагов   а гранью дружеских штыков   однажды русский генерал из гор к тифлису проезжал  ребенка пленного он вез  тот занемог  не перенес трудов далекого пути  он был  казалось  лет шести  как серна гор  пуглив и дик и слаб и гибок  как тростник  но в нем мучительный недуг развил тогда могучий дух его отцов  без жалоб он томился  даже слабый стон из детских гу
# ...

# %%
search_result = re.findall(r'\b\w*бо?л\w*\b', text) # с сочетанием 'бол'
print(search_result)
# Out:
# ['благовонный', 'благодать', 'бледен', 'близок', 'больной']

# %%
nltk_stopwords_ru = stopwords.words('russian')
print(nltk_stopwords_ru)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'в
# ...

# %%
nltk_stopwords_ru = nltk_stopwords_ru + ['благовонный', 'благодать', 'бледен', 'близок', 'больной']

# %%
print(text_norm) # из 2 задания (нижний регистр+без пунктуации)
# Out:
#   немного лет тому назад  там  где  сливаяся  шумят  обнявшись  будто две сестры  струи арагвы и куры  был монастырь  из за горы и нынче видит пешеход столбы обрушенных ворот  и башни  и церковный свод  но не курится уж под ним кадильниц благовонный дым  не слышно пенье в поздний час молящих иноков за нас  теперь один старик седой  развалин страж полуживой  людьми и смертию забыт  сметает пыль с могильных плит  которых надпись говорит о славе прошлой   и о том  как  удручен своим венцом  такой то царь  в такой то год  вручал россии свой народ  и божья благодать сошла на грузию  она цвела с тех пор в тени своих садов  не опасаяся врагов   а гранью дружеских штыков   однажды русский генерал из гор к тифлису проезжал  ребенка пленного он вез  тот занемог  не перенес трудов далекого пути  он был  казалось  лет шести  как серна гор  пуглив и дик и слаб и гибок  как тростник  но в нем мучительный недуг развил тогда могучий дух его отцов  без жалоб он томился  даже слабый стон из детских гу
# ...

# %%
naive_tokens = text_norm.split() # токенизация из 2 задания
print(naive_tokens)
# Out:
# ['немного', 'лет', 'тому', 'назад', 'там', 'где', 'сливаяся', 'шумят', 'обнявшись', 'будто', 'две', 'сестры', 'струи', 'арагвы', 'и', 'куры', 'был', 'монастырь', 'из', 'за', 'горы', 'и', 'нынче', 'видит', 'пешеход', 'столбы', 'обрушенных', 'ворот', 'и', 'башни', 'и', 'церковный', 'свод', 'но', 'не', 'курится', 'уж', 'под', 'ним', 'кадильниц', 'благовонный', 'дым', 'не', 'слышно', 'пенье', 'в', 'поздний', 'час', 'молящих', 'иноков', 'за', 'нас', 'теперь', 'один', 'старик', 'седой', 'развалин', 'страж', 'полуживой', 'людьми', 'и', 'смертию', 'забыт', 'сметает', 'пыль', 'с', 'могильных', 'плит', 'которых', 'надпись', 'говорит', 'о', 'славе', 'прошлой', 'и', 'о', 'том', 'как', 'удручен', 'своим', 'венцом', 'такой', 'то', 'царь', 'в', 'такой', 'то', 'год', 'вручал', 'россии', 'свой', 'народ', 'и', 'божья', 'благодать', 'сошла', 'на', 'грузию', 'она', 'цвела', 'с', 'тех', 'пор', 'в', 'тени', 'своих', 'садов', 'не', 'опасаяся', 'врагов', 'а', 'гранью', 'дружеских', 'штыков', 'однажды', 'рус
# ...

# %%
nltk_stopwords_ru = stopwords.words('russian')
print(nltk_stopwords_ru)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'в
# ...

# %%
nltk_stopwords_ru = nltk_stopwords_ru + ['благовонный', 'благодать', 'бледен', 'близок', 'больной']

# %%
nltk_stopwords_ru = stopwords.words('russian')
nltk_stopwords_ru = nltk_stopwords_ru + ['благовонный', 'благодать', 'бледен', 'близок', 'больной']
print(nltk_stopwords_ru)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'в
# ...

# %%
print(nltk_stopwords_ru)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'в
# ...

# %%
print(nltk_stopwords_ru)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'в
# ...

# %%
list_no_stop_words = [] # список
for token in (naive_tokens): 
    if token not in nltk_stopwords_ru:
        list_no_stop_words.append(token) # новый список токенов без стоп-слов.
print(list_no_stop_words)
# Out:
# ['немного', 'лет', 'тому', 'назад', 'сливаяся', 'шумят', 'обнявшись', 'две', 'сестры', 'струи', 'арагвы', 'куры', 'монастырь', 'горы', 'нынче', 'видит', 'пешеход', 'столбы', 'обрушенных', 'ворот', 'башни', 'церковный', 'свод', 'курится', 'кадильниц', 'дым', 'слышно', 'пенье', 'поздний', 'час', 'молящих', 'иноков', 'старик', 'седой', 'развалин', 'страж', 'полуживой', 'людьми', 'смертию', 'забыт', 'сметает', 'пыль', 'могильных', 'плит', 'которых', 'надпись', 'говорит', 'славе', 'прошлой', 'удручен', 'своим', 'венцом', 'царь', 'год', 'вручал', 'россии', 'свой', 'народ', 'божья', 'сошла', 'грузию', 'цвела', 'тех', 'пор', 'тени', 'своих', 'садов', 'опасаяся', 'врагов', 'гранью', 'дружеских', 'штыков', 'однажды', 'русский', 'генерал', 'гор', 'тифлису', 'проезжал', 'ребенка', 'пленного', 'вез', 'занемог', 'перенес', 'трудов', 'далекого', 'пути', 'казалось', 'лет', 'шести', 'серна', 'гор', 'пуглив', 'дик', 'слаб', 'гибок', 'тростник', 'нем', 'мучительный', 'недуг', 'развил', 'могучий', 'дух'
# ...

# %%
print(len(list_no_stop_words))  # без 'благовонный', 'благодать', 'бледен', 'близок', 'больной' 210 слов. Было 215
# Out:
# 210
